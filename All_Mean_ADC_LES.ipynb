# %%
import matplotlib.pyplot as plt # plotting
import numpy as np              # working with number arrays etc.
from netCDF4 import Dataset     # reading netcdf files

#pathles="/Users/amrapalli/runs/cvmix/cvmix_analysis/"
pathles="/Users/amrapallig/Desktop/cvmix/"
path="/Users/amrapallig/Desktop/cvmix/adc/convection/"
path2="/Users/amrapallig/run/cvmix_test/forward/output/convection/time_sensitivity/"

# %%
fig = plt.figure(figsize=(14,11))
t=96
t1=t-6

d=70
plt.subplot(221)



les= Dataset(pathles+"les/Cooling1.nc", mode='r')
plt.plot(np.mean(les.variables["temp"][t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=3)
les= Dataset(pathles+"les/Cooling2.nc", mode='r')
plt.plot(np.mean(les.variables["temp"][t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=3)
les= Dataset(pathles+"les/Cooling4.nc", mode='r')
plt.plot(np.mean(les.variables["temp"][t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=3)
les= Dataset(pathles+"les/Cooling16.nc", mode='r')
plt.plot(np.mean(les.variables["temp"][t1:t,:],axis=0),les.variables["zm"][:],'-m',alpha=0.6,linewidth=3)

plt.legend(["Cooling1","Cooling2","Cooling4","Cooling16"],fontsize=14)

fh=Dataset(path+'output.0001-01-01_00.00_c1_1m_test2.nc', mode='r') 
mf = Dataset(path+'adcTurbulenceArrays_c1_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['temperature'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'--r',linewidth=3)
plt.plot((mf.variables['temperature'][0,0,:]),fh.variables['zMid'][1,1,:],':k')

fh=Dataset(path+'output.0001-01-01_00.00_c2_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c2_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['temperature'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'--b',linewidth=3)

fh=Dataset(path+'output.0001-01-01_00.00_c4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c4_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['temperature'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'--c',linewidth=3)

fh=Dataset(path+'output.0001-01-01_00.00_c16_1m_test3.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c16_1m_test3.nc', mode='r')  
plt.plot(np.mean(mf.variables['temperature'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'--m',linewidth=3)


plt.ylim(-d,1)
plt.xlim(13,20)

plt.xlabel('$\overline{\\theta}$ $(^0C)$',fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.grid()
plt.text(19,-50, r'(a)', fontsize=20)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(222)

les= Dataset(pathles+"les/Evap1.nc", mode='r')
plt.plot(np.mean(les.variables["salt"][t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=3)

les= Dataset(pathles+"les/Evap4.nc", mode='r')
plt.plot(np.mean(les.variables["salt"][t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=3)

fh=Dataset(path+'output.0001-01-01_00.00_e1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e1_1m_test2.nc', mode='r')  
plt.plot((mf.variables['salinity'][0,0,:]),fh.variables['zMid'][1,1,:],':k')

plt.plot(np.mean(mf.variables['salinity'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'--r',linewidth=3)

fh=Dataset(path+'output.0001-01-01_00.00_e4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e4_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['salinity'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'--b',linewidth=3)
plt.xlabel('$\overline{S}$ $(psu)$',fontsize=20)
#plt.ylabel('$Depth (m)$ ',fontsize=14)
#plt.title("$Q_H=-50$ $W/m^2$",fontsize=14)

plt.legend(["Evap1","Evap4"],fontsize=14)
plt.ylim(-50,1)
plt.xlim(35,36.5)
plt.text(36.25,-35, r'(b)', fontsize=20)
plt.grid()

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(223)
les= Dataset(pathles+"les/Strat20.nc", mode='r')
plt.plot(np.mean(les.variables["temp"][t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=3)
les= Dataset(pathles+"les/Strat10.nc", mode='r')
plt.plot(np.mean(les.variables["temp"][t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=3)
les= Dataset(pathles+"les/Strat1.nc", mode='r')
plt.plot(np.mean(les.variables["temp"][t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=3)

fh=Dataset(path+'output.0001-01-01_00.00_s20_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s20_1m_test2.nc', mode='r')  
plt.plot(mf.variables['temperature'][0,0,:],fh.variables['zMid'][1,1,:],':k')
plt.plot(np.mean(mf.variables['temperature'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'--r',linewidth=3)
fh=Dataset(path+'output.0001-01-01_00.00_s10_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s10_1m_test2.nc', mode='r')  
plt.plot(mf.variables['temperature'][0,0,:],fh.variables['zMid'][1,1,:],':k')
plt.plot(np.mean(mf.variables['temperature'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'--b',linewidth=3)
fh=Dataset(path+'output.0001-01-01_00.00_s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s1_1m_test2.nc', mode='r')  
plt.plot(mf.variables['temperature'][0,0,:],fh.variables['zMid'][1,1,:],':k')
plt.plot(np.mean(mf.variables['temperature'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'--c',linewidth=3)

plt.ylim(-d,1)
plt.xlim(15,20)
plt.grid()
plt.xlabel('$\overline{\\theta}$ $(^0C)$ ',fontsize=20)

plt.text(19,-50, r'(c)', fontsize=20)

plt.legend(["Strat20","Strat10","Strat1"],fontsize=14)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)

plt.subplot(224)

les= Dataset(pathles+"les/T1S0.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=3)
les= Dataset(pathles+"les/T1S1.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=3)
#plt.plot(density[0,:],les.variables["zm"][:],':k')

les= Dataset(pathles+"les/T1S3.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=3)

les= Dataset(pathles+"les/T1S15.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-m',alpha=0.6,linewidth=3)


plt.plot((density[0,:]),les.variables["zm"][:],':k')




fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--r',linewidth=3)




fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--b',linewidth=3)



fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--c',linewidth=3)


fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--m',linewidth=3)

plt.xlim(1026,1028)
plt.grid()
plt.xlabel('$\overline{\\rho}$ $kg/m^3$',fontsize=20)
#plt.title("$Q_H=-50$ $W/m^2$",fontsize=14)

plt.text(1027.75, -55,"(d)", fontsize=20)
plt.ylim(-70,1)

#plt.ticklabel_format(axis="x", type=(int))
#3ax.set_xticklabels(x.astype(int))
#plt.xlabels['1026', '1026.5', '1027', '1027.5', '1028']

plt.locator_params(axis='x', nbins=5)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.legend(["T1S0","T1S1","T1S3","T1S15"],fontsize=14)

# %%
les= Dataset(pathles+"les/T1S15.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
buoy=les.variables["buoy"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))
#plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=2)
plt.ylim(-70,1)
plt.plot(np.mean(temp[t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=2)


fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(temp[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--r',linewidth=2)

# %%
les= Dataset(pathles+"les/T1S15.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
buoy=les.variables["buoy"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))
#plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=2)
plt.ylim(-70,1)
plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=2)


fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--r',linewidth=2)

# %%
mf.variables.keys()
# Out:
# dict_keys(['xtime', 'KspsU', 'KspsD', 'eps', 'length', 'lendn', 'lenup', 'lenspsD', 'lenspsU', 'KhU', 'KhD', 'wt_spsU', 'wt_spsD', 'ws_spsU', 'ws_spsD', 'uw2', 'vw2', 'u2w', 'v2w', 'w2t', 'w2s', 'wt2', 'ws2', 'wts', 'uvw', 'uwt', 'vwt', 'uws', 'vws', 'areaFraction', 'Entrainment', 'Detrainment', 'inSituThermalExpansionCoeff', 'inSituSalineContractionCoeff', 'tumd', 'sumd', 'wumd', 'w2tend1', 'w2tend2', 'w2tend3', 'w2tend4', 'w2tend5', 'u2tend1', 'u2tend2', 'u2tend3', 'u2tend4', 'u2tend5', 'v2tend1', 'v2tend2', 'v2tend3', 'v2tend4', 'v2tend5', 'uwtend1', 'uwtend2', 'uwtend3', 'uwtend4', 'uwtend5', 'vwtend1', 'vwtend2', 'vwtend3', 'vwtend4', 'vwtend5', 'w3tend1', 'w3tend2', 'w3tend3', 'w3tend4', 'w3tend5', 'wttend1', 'wttend2', 'wttend3', 'wttend4', 'wttend5', 'wstend1', 'wstend2', 'wstend3', 'wstend4', 'wstend5', 'u2', 'v2', 'w2', 's2', 't2', 'uw', 'vw', 'wt', 'ws', 'w3', 'uv', 'ut', 'vt', 'us', 'vs', 'ts', 'Mc', 'velocityZonal', 'velocityMeridional', 'boundaryLayerDepth', 'w2cliptend
# ...

# %%
les= Dataset(pathles+"les/T1S15.nc", mode='r')

alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=les.variables["wb"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))
#plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=2)
plt.ylim(-70,1)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'--r',alpha=0.6,linewidth=2)

# %%
les.variables.keys()
# Out:
# dict_keys(['zm', 'Time', 'zt', 'dt', 'u2w', 'ws2', 'wt2', 'v2w', 'wb', 'uw2', 'K', 'w2press', 'vw2', 'v2', 'wt', 'ws', 'w2', 'rho', 'vw', 'PE', 'vvel', 'temp', 'wvel', 'uw', 't2', 'eps', 'u2', 'w2t', 'uvel', 'w4', 'w2s', 'H', 's2', 'w3', 'salt', 'buoy'])

# %%
#plt.subplot(224)

les= Dataset(pathles+"les/T1S0.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=2)
les= Dataset(pathles+"les/T1S1.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=2)
#plt.plot(density[0,:],les.variables["zm"][:],':k')

les= Dataset(pathles+"les/T1S3.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=2)

les= Dataset(pathles+"les/T1S15.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
temp=les.variables["temp"][:,:]
salt=les.variables["salt"][:,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),les.variables["zm"][:],'-m',alpha=0.6,linewidth=2)


plt.plot((density[0,:]),les.variables["zm"][:],':k')




fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--r',linewidth=2)




fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--b',linewidth=2)



fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--c',linewidth=2)


fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
temp=mf.variables["temperature"][:,0,:]
salt=mf.variables["salinity"][:,0,:]
density= rho*(1.0-alpha*(temp-20)+beta*(salt-35))

plt.plot(np.mean(density[t1:t,:],axis=0),fh.variables['zMid'][1,1,:],'--m',linewidth=2)

plt.xlim(1026,1028)
plt.grid()
plt.xlabel('$\overline{\\rho}$ $kg/m^3$',fontsize=20)
#plt.title("$Q_H=-50$ $W/m^2$",fontsize=14)

plt.text(1027.75, -55,"(d)", fontsize=20)
plt.ylim(-70,1)

#plt.ticklabel_format(axis="x", type=(int))
#3ax.set_xticklabels(x.astype(int))
#plt.xlabels['1026', '1026.5', '1027', '1027.5', '1028']

plt.locator_params(axis='x', nbins=5)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(["T1S0","T1S1","T1S3","T1S15"],fontsize=14)

# %%
fh=Dataset(path+'output.0001-01-01_00.00_s20_5m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s20_5m_test2.nc', mode='r')  
plt.plot(mf.variables['temperature'][0,0,:],fh.variables['zMid'][1,1,:],'*k')
plt.plot(np.mean(mf.variables['temperature'][t1:t,0,:],axis=0),fh.variables['zMid'][1,1,:],'*c',linewidth=2)
#plt.ylim(-d,1)
#plt.xlim(15,20)
plt.grid()
plt.xlabel('$\overline{\\theta}$ $(^0C)$ ',fontsize=20)
# Out:
# Text(0.5, 0, '$\\overline{\\theta}$ $(^0C)$ ')
