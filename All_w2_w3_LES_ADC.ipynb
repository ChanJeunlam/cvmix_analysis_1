# %%
import matplotlib.pyplot as plt # plotting
import numpy as np              # working with number arrays etc.
from netCDF4 import Dataset     # reading netcdf files

pathles="/Users/amrapallig/Desktop/cvmix/"
path="/Users/amrapallig/Desktop/cvmix/adc/convection/"

# %%
fig = plt.figure(figsize=(13,11))
t=96
t1=t-6
lw=3
d=70
plt.subplot(221)

les= Dataset(pathles+"les/Cooling1.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-r',linewidth=lw)
les= Dataset(pathles+"les/Cooling2.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-b',linewidth=lw)
les= Dataset(pathles+"les/Cooling4.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-c',linewidth=lw)
les= Dataset(pathles+"les/Cooling16.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-m',linewidth=lw)


fh=Dataset(path+'output.0001-01-01_00.00_c1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c1_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)

fh=Dataset(path+'output.0001-01-01_00.00_c2_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c2_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)



fh=Dataset(path+'output.0001-01-01_00.00_c4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c4_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--c',linewidth=lw)

fh=Dataset(path+'output.0001-01-01_00.00_c16_1m_test3.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c16_1m_test3.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--m',linewidth=lw)


plt.text(0.5e-4, -55,"(a)",fontsize=20)
plt.grid()

plt.ylim(-d,1)
plt.xlabel('$\overline{{w^\prime}^2}$ $(m^2/s^2)$  ',fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.legend(["Cooling1","Cooling2","Cooling4","Cooling16"],fontsize=14)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(222)
les= Dataset(pathles+"les/Evap1.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_e1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e1_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-r',linewidth=lw)

les= Dataset(pathles+"les/Evap4.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-b',linewidth=lw)

plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)

fh=Dataset(path+'output.0001-01-01_00.00_e4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e4_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.ylim(-40,1)
plt.xlabel('$\overline{{w^\prime}^2}$ $(m^2/s^2)$  ',fontsize=20)
plt.text(1e-5, -35,"(b)",fontsize=20)
plt.grid()
plt.legend(["Evap1","Evap4"],fontsize=14)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(223)
les= Dataset(pathles+"les/Strat20.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-r',linewidth=lw)
les= Dataset(pathles+"les/Strat10.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-b',linewidth=lw)
les= Dataset(pathles+"les/Strat1.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-c',linewidth=lw)


fh=Dataset(path+'output.0001-01-01_00.00_s20_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s20_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)

fh=Dataset(path+'output.0001-01-01_00.00_s10_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s10_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.ylim(-70,1)
plt.xlabel('$\overline{w^2}$ $(m^2/s^2)$',fontsize=14)

fh=Dataset(path+'output.0001-01-01_00.00_s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s1_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--c',linewidth=lw)

plt.xlabel('$\overline{{w^\prime}^2}$ $(m^2/s^2)$  ',fontsize=20)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.text(2e-5, -55,"(c)",fontsize=20)
plt.grid()
plt.legend(["Strat20","Strat10","Strat1"],fontsize=14)

plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(224)

les= Dataset(pathles+"les/T1S0.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-r',linewidth=lw)
les= Dataset(pathles+"les/T1S1.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-b',linewidth=lw)
les= Dataset(pathles+"les/T1S3.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-c',linewidth=lw)
les= Dataset(pathles+"les/T1S15.nc", mode='r')
plt.plot(np.mean(les.variables["w2"][t1:t,:],axis=0),les.variables["zm"][:],'-m',linewidth=lw)


fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)

fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)



fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--c',linewidth=lw)

fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
plt.plot(np.mean(mf.variables['w2'][t1:t,0,:-1],axis=0),fh.variables['zTop'][1,1,:],'--m',linewidth=lw)


plt.text(0.5e-4, -55,"(d)",fontsize=20)
plt.grid()

plt.ylim(-d,1)
plt.xlabel('$\overline{{w^\prime}^2}$ $(m^2/s^2)$  ',fontsize=20)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.legend(["T1S0","T1S1","T1S3","T1S15"],fontsize=14)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
# Out:
# (array([-70., -60., -50., -40., -30., -20., -10.,   0.,  10.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
fig = plt.figure(figsize=(13,10))
t=96
t1=t-6

d=70
plt.subplot(221)

les= Dataset(pathles+"les/Cooling1.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-r',linewidth=2)
les= Dataset(pathles+"les/Cooling2.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-b',linewidth=2)
les= Dataset(pathles+"les/Cooling4.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-c',linewidth=2)
les= Dataset(pathles+"les/Cooling16.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-m',linewidth=2)


fh=Dataset(path+'output.0001-01-01_00.00_c1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c1_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--r',linewidth=2)

fh=Dataset(path+'output.0001-01-01_00.00_c2_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c2_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--b',linewidth=2)



fh=Dataset(path+'output.0001-01-01_00.00_c4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c4_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--c',linewidth=2)

fh=Dataset(path+'output.0001-01-01_00.00_c16_1m_test3.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c16_1m_test3.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--m',linewidth=2)


#plt.text(0.5e-4, -55,"(a)",fontsize=20)
plt.grid()

plt.ylim(-d,1)
plt.xlabel('$\overline{w^3}$ $(m^3/s^3)$  ',fontsize=20)
plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.legend(["Cooling1","Cooling2","Cooling4","Cooling16"],fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.subplot(222)
les= Dataset(pathles+"les/Evap1.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_e1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e1_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-r',linewidth=2)

les= Dataset(pathles+"les/Evap4.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-b',linewidth=2)

plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--r',linewidth=2)

fh=Dataset(path+'output.0001-01-01_00.00_e4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e4_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--b',linewidth=2)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.ylim(-40,1)
plt.xlabel('$\overline{w^3}$ $(m^3/s^3)$ ',fontsize=20)
#plt.text(1e-5, -35,"(b)",fontsize=20)
plt.grid()
plt.legend(["Evap1","Evap4"],fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.subplot(223)
les= Dataset(pathles+"les/Strat20.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-r',linewidth=2)
les= Dataset(pathles+"les/Strat10.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-b',linewidth=2)
les= Dataset(pathles+"les/Strat1.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-c',linewidth=2)


fh=Dataset(path+'output.0001-01-01_00.00_s20_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s20_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--r',linewidth=2)

fh=Dataset(path+'output.0001-01-01_00.00_s10_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s10_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--b',linewidth=2)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.ylim(-70,1)
plt.xlabel('$\overline{w^2}$ $(m^2/s^2)$',fontsize=14)

fh=Dataset(path+'output.0001-01-01_00.00_s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s1_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--c',linewidth=2)

plt.xlabel('$\overline{w^3}$ $(m^3/s^3)$ ',fontsize=20)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
#plt.text(2e-5, -55,"(c)",fontsize=20)
plt.grid()
plt.legend(["Strat20","Strat10","Strat1"],fontsize=14)

plt.ylabel('$Depth$ $(m)$ ',fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.subplot(224)

les= Dataset(pathles+"les/T1S0.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-r',linewidth=2)
les= Dataset(pathles+"les/T1S1.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-b',linewidth=2)
les= Dataset(pathles+"les/T1S3.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-c',linewidth=2)
les= Dataset(pathles+"les/T1S15.nc", mode='r')
plt.plot(np.mean(les.variables["w3"][t1:t,:],axis=0),les.variables["zm"][:],'-m',linewidth=2)


fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--r',linewidth=2)

fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--b',linewidth=2)



fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--c',linewidth=2)

fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
plt.plot(np.mean(mf.variables['w3'][t1:t,0,:-1],axis=0),fh.variables['zMid'][1,1,:-1],'--m',linewidth=2)


#plt.text(0.5e-4, -55,"(d)",fontsize=20)
plt.grid()

plt.ylim(-d,1)
plt.xlabel('$\overline{w^3}$ $(m^3/s^3)$  ',fontsize=20)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))

plt.legend(["T1S0","T1S1","T1S3","T1S15"],fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
# Out:
# (array([-70., -60., -50., -40., -30., -20., -10.,   0.,  10.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
