# %%
import matplotlib.pyplot as plt # plotting
import numpy as np              # working with number arrays etc.
from netCDF4 import Dataset     # reading netcdf files

pathles="/Users/amrapallig/Desktop/cvmix/"
path="/Users/amrapallig/Desktop/cvmix/adc/convection/"
#path2="/Users/amrapallig/run/cvmix_test/forward/output/convection/time_sensitivity/"

# %%
fig = plt.figure(figsize=(14,11))
t=96
t1=t-6
lw=3
d=70
plt.subplot(221)

les= Dataset(pathles+"les/Cooling1.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_c1_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=lw)
les= Dataset(pathles+"les/Cooling2.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=lw)
les= Dataset(pathles+"les/Cooling4.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=lw)
les= Dataset(pathles+"les/Cooling16.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-m',alpha=0.6,linewidth=lw)

plt.legend(["Cooling1","Cooling2","Cooling4","Cooling16"],fontsize=14)



mf = Dataset(path+'adcTurbulenceArrays_c1_1m_test2.nc', mode='r') 
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.ylim(-d,1)
plt.xlabel('$\overline{w\prime\\theta\prime}$ ',fontsize=20)
plt.ylabel('$Depth $ $(m)$ ',fontsize=20)

plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-m',linewidth=lw)
d=40

fh=Dataset(path+'output.0001-01-01_00.00_c2_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c2_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)
plt.ylim(-d,1)

plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)



fh=Dataset(path+'output.0001-01-01_00.00_c4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c4_1m_test2.nc', mode='r')  


plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--c',linewidth=lw)
plt.ylim(-d,1)
plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)

d=70
fh=Dataset(path+'output.0001-01-01_00.00_c16_1m_test3.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c16_1m_test3.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--m',linewidth=lw)
plt.ylim(-d,1)
plt.xlabel('$\overline{w^\prime\\theta^\prime}$ $(K$ $ms^{-1})$',fontsize=20)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.text(0.5e-4,-60, r'(a)', fontsize=20)

plt.grid()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(222)
d=40
les= Dataset(pathles+"les/Evap1.nc", mode='r')
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/Evap4.nc", mode='r')
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=lw)


fh=Dataset(path+'output.0001-01-01_00.00_e1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e1_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.ylim(-d,0)


fh=Dataset(path+'output.0001-01-01_00.00_e4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e4_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)
plt.ylim(-d,1)

plt.grid()
plt.xlabel('$\overline{w^\prime s^\prime}$ $(psu$ $ms^{-1})$',fontsize=20)

plt.text(-0.5e-5,-36, r'(b)', fontsize=20)
plt.legend(["Evap1","Evap4"],fontsize=14)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(223)


les= Dataset(pathles+"les/Strat20.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/Strat10.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/Strat1.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=lw)


fh=Dataset(path+'output.0001-01-01_00.00_s20_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s20_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.ylim(-d,1)

fh=Dataset(path+'output.0001-01-01_00.00_s10_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s10_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)
plt.ylim(-d,1)

d=70

fh=Dataset(path+'output.0001-01-01_00.00_s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s1_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--c',linewidth=lw)
plt.ylim(-d,1)




plt.grid()
plt.xlabel('$\overline{w^\prime\\theta^\prime}$ $(K$ $ms^{-1})$ ',fontsize=20)
plt.text(1e-5,-60, r'(c)', fontsize=20)
plt.legend(["Strat20","Strat10","Strat1"],fontsize=14)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('$Depth $ $(m)$ ',fontsize=20)

plt.subplot(224)

t=96
t1=t-2

les= Dataset(pathles+"les/T1S0.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/T1S1.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/T1S3.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/T1S15.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-m',alpha=0.6,linewidth=lw)


fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)

t=96
t1=t-12

fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)

fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--c',linewidth=lw)



fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)

plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--m',linewidth=lw)

#plt.xlim(1026,1027.5)
plt.grid()
plt.xlabel('$\overline{w^\prime b^\prime}$ $(m^2s^{-3})$ ',fontsize=20)
#plt.title("$Q_H=-50$ $W/m^2$",fontsize=14)
plt.legend(["T1S0","T1S1","T1S3","T1S15"],fontsize=14)

plt.ylim(-70,1)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.text(1e-7,-60, r'(d)', fontsize=20)
# Out:
# Text(1e-07, -60, '(d)')

# %%
plt.figure(figsize=(15,4))
t=96
t1=t-12


plt.subplot(131)

d=60

les= Dataset(pathles+"les/T1S0.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-r')
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r')
plt.ylim(-d,1)
plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)
plt.ylabel('$Depth (m)$ ',fontsize=14)

plt.legend(["LES","ADC"])

les= Dataset(pathles+"les/T1S1.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-b')
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b')
plt.ylim(-d,1)
plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)


les= Dataset(pathles+"les/T1S3.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-c')
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--c')
plt.ylim(-d,1)
plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)

les= Dataset(pathles+"les/T1S15.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-m')
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--m')
plt.ylim(-d,1)
plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)
plt.grid()
plt.text(1e-5,-55, r'(d)', fontsize=15)

plt.subplot(132)

d=60

les= Dataset(pathles+"les/T1S0.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-r')
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r')
plt.ylim(-d,1)
plt.xlabel('$\overline{ws}$ ',fontsize=14)

plt.legend(["LES","ADC"])

les= Dataset(pathles+"les/T1S1.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-b')
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b')
plt.ylim(-d,1)


les= Dataset(pathles+"les/T1S3.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-c')
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--c')
plt.ylim(-d,1)

les= Dataset(pathles+"les/T1S15.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-m')
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--m')
plt.ylim(-d,1)
plt.xlabel('$\overline{ws}$ ',fontsize=14)

plt.grid()
plt.text(-1e-5,-55, r'(e)', fontsize=15)


plt.subplot(133)

les= Dataset(pathles+"les/T1S0.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--r')



les= Dataset(pathles+"les/T1S1.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-b')
fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--b')

les= Dataset(pathles+"les/T1S3.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-c')
fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--c')


les= Dataset(pathles+"les/T1S15.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-m')
fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)

plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--m')

#plt.xlim(1026,1027.5)
plt.grid()
plt.xlabel('$\overline{wb}$ ',fontsize=14)
#plt.title("$Q_H=-50$ $W/m^2$",fontsize=14)
plt.legend(["LES","ADC"])

plt.ylim(-50,1)
# Out:
# (-50.0, 1.0)

# %%
plt.figure(figsize=(15,4))
t=96
t1=t-6


plt.subplot(131)

d=30

les= Dataset(pathles+"les/T1S0.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-r')
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r')
plt.ylim(-d,1)
plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)
plt.ylabel('$Depth (m)$ ',fontsize=14)

plt.legend(["LES","ADC"])






plt.subplot(132)

d=60

les= Dataset(pathles+"les/T1S0.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-r')
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r')
plt.ylim(-d,1)
plt.xlabel('$\overline{ws}$ ',fontsize=14)

plt.legend(["LES","ADC"])






plt.subplot(133)

les= Dataset(pathles+"les/T1S0.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--r')








#plt.xlim(1026,1027.5)
plt.grid()
plt.xlabel('$\overline{wb}$ ',fontsize=14)
#plt.title("$Q_H=-50$ $W/m^2$",fontsize=14)
plt.legend(["LES","ADC"])

plt.ylim(-50,1)
# Out:
# (-50.0, 1.0)

# %%
plt.figure(figsize=(15,4))
t=96
t1=t-6


plt.subplot(131)

d=30

les= Dataset(pathles+"les/T1S1.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-b')
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b')
plt.ylim(-d,1)
plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)
plt.ylabel('$Depth (m)$ ',fontsize=14)

plt.legend(["LES","ADC"])






plt.subplot(132)

d=60

les= Dataset(pathles+"les/T1S1.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-b')
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsU'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b')
plt.ylim(-d,1)
plt.xlabel('$\overline{ws}$ ',fontsize=14)

plt.legend(["LES","ADC"])






plt.subplot(133)

les= Dataset(pathles+"les/T1S1.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-b')
fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsU'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsU'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--b')








#plt.xlim(1026,1027.5)
plt.grid()
plt.xlabel('$\overline{wb}$ ',fontsize=14)
#plt.title("$Q_H=-50$ $W/m^2$",fontsize=14)
plt.legend(["LES","ADC"])

plt.ylim(-50,1)
# Out:
# (-50.0, 1.0)

# %%
fig = plt.figure(figsize=(14,11))
t=96
t1=t-6
lw=3
d=70
plt.subplot(221)

les= Dataset(pathles+"les/Cooling1.nc", mode='r')
fh=Dataset(path+'output.0001-01-01_00.00_c1_1m_test2.nc', mode='r')  
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=lw)
les= Dataset(pathles+"les/Cooling2.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=lw)
les= Dataset(pathles+"les/Cooling4.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=lw)
les= Dataset(pathles+"les/Cooling16.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-m',alpha=0.6,linewidth=lw)

plt.legend(["Cooling1","Cooling2","Cooling4","Cooling16"],fontsize=14)



mf = Dataset(path+'adcTurbulenceArrays_c1_1m_test2.nc', mode='r') 
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.ylim(-d,1)
plt.xlabel('$\overline{w\prime\\theta\prime}$ ',fontsize=20)
plt.ylabel('$Depth $ $(m)$ ',fontsize=20)

plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-m',linewidth=lw)
d=40

fh=Dataset(path+'output.0001-01-01_00.00_c2_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c2_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)
plt.ylim(-d,1)

plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)



fh=Dataset(path+'output.0001-01-01_00.00_c4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c4_1m_test2.nc', mode='r')  


plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--c',linewidth=lw)
plt.ylim(-d,1)
plt.xlabel('$\overline{w\\theta}$ ',fontsize=14)

d=70
fh=Dataset(path+'output.0001-01-01_00.00_c16_1m_test3.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c16_1m_test3.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--m',linewidth=lw)
plt.ylim(-d,1)
plt.xlabel('$\overline{w^\prime\\theta^\prime}$ $(K$ $ms^{-1})$',fontsize=20)
plt.ticklabel_format(axis="x", style="sci", scilimits=(0,0))
plt.text(0.5e-4,-60, r'(a)', fontsize=20)

plt.grid()
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(222)
d=40
les= Dataset(pathles+"les/Evap1.nc", mode='r')
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/Evap4.nc", mode='r')
plt.plot(np.mean(les.variables["ws"][t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=lw)


fh=Dataset(path+'output.0001-01-01_00.00_e1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e1_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.ylim(-d,0)


fh=Dataset(path+'output.0001-01-01_00.00_e4_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_e4_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['ws'][t1:t,0,:-1]+mf.variables['ws_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)
plt.ylim(-d,1)

plt.grid()
plt.xlabel('$\overline{w^\prime s^\prime}$ $(psu$ $ms^{-1})$',fontsize=20)

plt.text(-0.5e-5,-36, r'(b)', fontsize=20)
plt.legend(["Evap1","Evap4"],fontsize=14)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)

plt.subplot(223)


les= Dataset(pathles+"les/Strat20.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/Strat10.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/Strat1.nc", mode='r')
plt.plot(np.mean(les.variables["wt"][t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=lw)


fh=Dataset(path+'output.0001-01-01_00.00_s20_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s20_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)
plt.ylim(-d,1)

fh=Dataset(path+'output.0001-01-01_00.00_s10_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s10_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)
plt.ylim(-d,1)

d=70

fh=Dataset(path+'output.0001-01-01_00.00_s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_s1_1m_test2.nc', mode='r')  
plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--c',linewidth=lw)
plt.ylim(-d,1)




plt.grid()
plt.xlabel('$\overline{w^\prime\\theta^\prime}$ $(K$ $ms^{-1})$ ',fontsize=20)
plt.text(1e-5,-60, r'(c)', fontsize=20)
plt.legend(["Strat20","Strat10","Strat1"],fontsize=14)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.ylabel('$Depth $ $(m)$ ',fontsize=20)

plt.subplot(224)

t=96
t1=t-2

les= Dataset(pathles+"les/T1S0.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-r',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/T1S1.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-b',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/T1S3.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-c',alpha=0.6,linewidth=lw)

les= Dataset(pathles+"les/T1S15.nc", mode='r')
alpha=2e-4; beta=8e-4; g=9.81; rho=1026
wt=les.variables["wt"][:,:]
ws=les.variables["ws"][:,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:],axis=0),les.variables["zm"][:],'-m',alpha=0.6,linewidth=lw)


fh=Dataset(path+'output.0001-01-01_00.00_t1s0_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s0_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsD'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsD'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--r',linewidth=lw)

t=96
t1=t-12

fh=Dataset(path+'output.0001-01-01_00.00_t1s1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s1_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsD'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsD'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--b',linewidth=lw)

fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsD'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsD'][:,0,:]
wb=g*(alpha*wt-beta*ws)
plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--c',linewidth=lw)



fh=Dataset(path+'output.0001-01-01_00.00_t1s15_1m_test2_dtp5.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s15_1m_test2_dtp5.nc', mode='r')  
wt=mf.variables["wt"][:,0,:]+mf.variables['wt_spsD'][:,0,:]
ws=mf.variables["ws"][:,0,:]+mf.variables['ws_spsD'][:,0,:]
wb=g*(alpha*wt-beta*ws)

plt.plot(np.mean(wb[t1:t,:-1],axis=0),fh.variables['zTop'][1,1,:],'--m',linewidth=lw)

#plt.xlim(1026,1027.5)
plt.grid()
plt.xlabel('$\overline{w^\prime b^\prime}$ $(m^2s^{-3})$ ',fontsize=20)
#plt.title("$Q_H=-50$ $W/m^2$",fontsize=14)
plt.legend(["T1S0","T1S1","T1S3","T1S15"],fontsize=14)

plt.ylim(-70,1)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.text(1e-7,-60, r'(d)', fontsize=20)
# Out:
# Text(1e-07, -60, '(d)')

# %%
fh=Dataset(path+'output.0001-01-01_00.00_t1s3_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_t1s3_1m_test2.nc', mode='r')  
plt.plot(mf.variables['wt_spsD'][95,0,:-1],fh.variables['zTop'][1,1,:],'-')
plt.plot(mf.variables['wt_spsU'][95,0,:-1],fh.variables['zTop'][1,1,:],'--')
plt.ylim(-40,1)
plt.legend(['wt_spsD','wt_spsU'])
#plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--m',linewidth=lw)

# %%
fh=Dataset(path+'output.0001-01-01_00.00_c1_1m_test2.nc', mode='r')  
mf = Dataset(path+'adcTurbulenceArrays_c1_1m_test2.nc', mode='r')  
plt.plot(mf.variables['wt_spsD'][95,0,:-1],fh.variables['zTop'][1,1,:],'-')
plt.plot(mf.variables['wt_spsU'][95,0,:-1],fh.variables['zTop'][1,1,:],'--')
plt.ylim(-40,1)
plt.legend(['wt_spsD','wt_spsU'])
#plt.plot(np.mean((mf.variables['wt'][t1:t,0,:-1]+mf.variables['wt_spsD'][t1:t,0,:-1]),axis=0),fh.variables['zTop'][1,1,:],'--m',linewidth=lw)
